# %%
import pandas as pd

# %%
pd.read_csv('2020/prosecutors_2019.csv')
# Out:
#                 name                                           position  \
# 0       Краснов И.В.          Генеральный прокурор Российской Федерации
# 1       Буксман А.Э.  первый заместитель Генерального  прокурора Рос...
# 2       Лопатин Г.Б.  заместитель Генерального прокурора Российской ...
# 3    Винниченко Н.А.  заместитель Генерального прокурора Российской ...
# 4        Кикоть А.В.  заместитель Генерального прокурора Российской ...
# ..               ...                                                ...
# 183     Дибиров М.Д.  заместитель начальника управления Главного упр...
# 184      Лисьев А.В.                               начальник управления
# 185       Бакун В.М.                 заместитель начальника управления
# 186  Слепокуров В.М.                  заместитель начальника управления
# 187       Пухов А.В.                  заместитель начальника управления
#
#       spouse  staf_income  spouse_income minor_child  count_real_est  \
# ...

# %%
df = pd.read_csv('2020/prosecutors_2019.csv') 
df.sort_values(by=['real_est_sq'],inplace = True, ascending=False)
#df.sort_values(by=['staf_income'],inplace = True, ascending=False)
#df.sort_values(by=['spouse_income'],inplace = True, ascending=False)

df.to_csv("2020/bigger_real_est_sq_prosecutors_2019.csv",index=False)
